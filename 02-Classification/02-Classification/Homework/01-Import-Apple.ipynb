# %% [markdown]
# # Import

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display, Markdown

sns.set_theme(style="darkgrid")
pd.set_option('display.max_columns', None)  

import sys, os, yaml

DATASET = "Apple-Quality"
COLAB = 'google.colab' in sys.modules

DEBUG = False
SEED = 666

# %%
COLAB = 'google.colab' in sys.modules

if COLAB:
  from google.colab import drive
  if not os.path.isdir("/content/gdrive"):
    drive.mount("/content/gdrive")
    d = "/content/gdrive/MyDrive/datasets"
    if not os.path.isdir(ROOT+d): os.makedirs(ROOT+d)
  ROOT = f"/content/gdrive/MyDrive/datasets/{DATASET.replace(' ','_')}/"
  if not os.path.isdir(ROOT): os.makedirs(ROOT)
else:
  ROOT = "./"

def makedirs(d):
  if COLAB:
    if not os.path.isdir(ROOT+d): os.makedirs(ROOT+d)
  else:
    if not os.path.isdir(ROOT+d): os.makedirs(ROOT+d, mode=0o777, exist_ok=True)

for d in ['orig','data','output']: makedirs(d)

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv(f"{ROOT}/orig/apple_quality.csv")

# %%
df.columns = [c.title().replace(' ', '_') for c in df.columns]
df.columns
# Out:
# Index(['A_Id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_Id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
df.describe().T.style.background_gradient(axis=0, cmap='cubehelix')
# Out:
# <style type="text/css">
# #T_681b0_row0_col0, #T_681b0_row1_col0, #T_681b0_row1_col1, #T_681b0_row1_col2, #T_681b0_row1_col3, #T_681b0_row1_col4, #T_681b0_row1_col5, #T_681b0_row1_col6, #T_681b0_row1_col7, #T_681b0_row2_col0, #T_681b0_row2_col1, #T_681b0_row2_col2, #T_681b0_row2_col3, #T_681b0_row2_col4, #T_681b0_row2_col5, #T_681b0_row2_col6, #T_681b0_row2_col7, #T_681b0_row3_col0, #T_681b0_row3_col1, #T_681b0_row3_col2, #T_681b0_row3_col4, #T_681b0_row3_col5, #T_681b0_row3_col6, #T_681b0_row3_col7, #T_681b0_row4_col0, #T_681b0_row4_col1, #T_681b0_row4_col2, #T_681b0_row4_col4, #T_681b0_row4_col5, #T_681b0_row4_col6, #T_681b0_row4_col7, #T_681b0_row5_col0, #T_681b0_row5_col1, #T_681b0_row5_col2, #T_681b0_row5_col4, #T_681b0_row5_col5, #T_681b0_row5_col6, #T_681b0_row5_col7, #T_681b0_row6_col0, #T_681b0_row6_col1, #T_681b0_row6_col2, #T_681b0_row6_col4, #T_681b0_row6_col5, #T_681b0_row6_col6, #T_681b0_row6_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_681b0_row0_col1, #T_681b0_row0_col2, #T_681b0_row0_col3, #T_681b0_row0_col4, #T_681b0_row0_col5, #T_681b0_row0_col6, #T_681b0_row0_col7 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_681b0_row3_col3 {
#   background-color: #0e050f;
#   color: #f1f1f1;
# }
# #T_681b0_row4_col3 {
#   background-color: #192845;
#   color: #f1f1f1;
# }
# #T_681b0_row5_col3 {
#   background-color: #192d48;
#   color: #f1f1f1;
# }
# #T_681b0_row6_col3 {
#   background-color: #17344c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_681b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_681b0_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_681b0_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_681b0_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_681b0_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_681b0_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_681b0_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_681b0_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_681b0_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_681b0_level0_row0" class="row_heading level0 row0" >A_Id</th>
#       <td id="T_681b0_row0_col0" class="data row0 col0" >4000.000000</td>
#       <td id="T_681b0_row0_col1" class="data row0 col1" >1999.500000</td>
#       <td id="T_681b0_row0_col2" class="data row0 col2" >1154.844867</td>
#       <td id="T_681b0_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_681b0_row0_col4" class="data row0 col4" >999.750000</td>
#       <td id="T_681b0_row0_col5" class="data row0 col5" >1999.500000</td>
#       <td id="T_681b0_row0_col6" class="data row0 col6" >2999.250000</td>
#       <td id="T_681b0_row0_col7" class="data row0 col7" >3999.000000</td>
#     </tr>
#     <tr>
#       <th id="T_681b0_level0_row1" class="row_heading level0 row1" >Size</th>
#       <td id="T_681b0_row1_col0" class="data row1 col0" >4000.000000</td>
#       <td id="T_681b0_row1_col1" class="data row1 col1" >-0.503015</td>
#       <td id="T_681b0_row1_col2" class="data row1 col2" >1.928059</td>
#       <td id="T_681b0_row1_col3" class="data row1 col3" >-7.151703</td>
#       <td id="T_681b0_row1_col4" class="data row1 col4" >-1.816765</td>
#       <td id="T_681b0_row1_col5" class="data row1 col5" >-0.513703</td>
#       <td id="T_681b0_row1_col6" class="data row1 col6" >0.805526</td>
#       <td id="T_681b0_row1_col7" class="data row1 col7" >6.406367</td>
#     </tr>
#     <tr>
#       <th id="T_681b0_level0_row2" class="row_heading level0 row2" >Weight</th>
#       <td id="T_681b0_row2_col0" class="data row2 col0" >4000.000000</td>
#       <td id="T_681b0_row2_col1" class="data row2 col1" >-0.989547</td>
#       <td id="T_681b0_row2_col2" class="data row2 col2" >1.602507</td>
#       <td id="T_681b0_row2_col3" class="data row2 col3" >-7.149848</td>
#       <td id="T_681b0_row2_col4" class="data row2 col4" >-2.011770</td>
#       <td id="T_681b0_row2_col5" class="data row2 col5" >-0.984736</td>
#       <td id="T_681b0_row2_col6" class="data row2 col6" >0.030976</td>
#       <td id="T_681b0_row2_col7" class="data row2 col7" >5.790714</td>
#     </tr>
#     <tr>
#       <th id="T_681b0_level0_row3" class="row_heading level0 row3" >Sweetness</th>
#       <td id="T_681b0_row3_col0" class="data row3 col0" >4000.000000</td>
#       <td id="T_681b0_row3_col1" class="data row3 col1" >-0.470479</td>
#       <td id="T_681b0_row3_col2" class="data row3 col2" >1.943441</td>
#       <td id="T_681b0_row3_col3" class="data row3 col3" >-6.894485</td>
#       <td id="T_681b0_row3_col4" class="data row3 col4" >-1.738425</td>
#       <td id="T_681b0_row3_col5" class="data row3 col5" >-0.504758</td>
#       <td id="T_681b0_row3_col6" class="data row3 col6" >0.801922</td>
#       <td id="T_681b0_row3_col7" class="data row3 col7" >6.374916</td>
#     </tr>
#     <tr>
#       <th id="T_681b0_level0_row4" class="row_heading level0 row4" >Crunchiness</th>
#       <td id="T_681b0_row4_col0" class="data row4 col0" >4000.000000</td>
#       <td id="T_681b0_row4_col1" class="data row4 col1" >0.985478</td>
#       <td id="T_681b0_row4_col2" class="data row4 col2" >1.402757</td>
#       <td id="T_681b0_row4_col3" class="data row4 col3" >-6.055058</td>
#       <td id="T_681b0_row4_col4" class="data row4 col4" >0.062764</td>
#       <td id="T_681b0_row4_col5" class="data row4 col5" >0.998249</td>
#       <td id="T_681b0_row4_col6" class="data row4 col6" >1.894234</td>
#       <td id="T_681b0_row4_col7" class="data row4 col7" >7.619852</td>
#     </tr>
#     <tr>
#       <th id="T_681b0_level0_row5" class="row_heading level0 row5" >Juiciness</th>
#       <td id="T_681b0_row5_col0" class="data row5 col0" >4000.000000</td>
#       <td id="T_681b0_row5_col1" class="data row5 col1" >0.512118</td>
#       <td id="T_681b0_row5_col2" class="data row5 col2" >1.930286</td>
#       <td id="T_681b0_row5_col3" class="data row5 col3" >-5.961897</td>
#       <td id="T_681b0_row5_col4" class="data row5 col4" >-0.801286</td>
#       <td id="T_681b0_row5_col5" class="data row5 col5" >0.534219</td>
#       <td id="T_681b0_row5_col6" class="data row5 col6" >1.835976</td>
#       <td id="T_681b0_row5_col7" class="data row5 col7" >7.364403</td>
#     </tr>
#     <tr>
#       <th id="T_681b0_level0_row6" class="row_heading level0 row6" >Ripeness</th>
#       <td id="T_681b0_row6_col0" class="data row6 col0" >4000.000000</td>
#       <td id="T_681b0_row6_col1" class="data row6 col1" >0.498277</td>
#       <td id="T_681b0_row6_col2" class="data row6 col2" >1.874427</td>
#       <td id="T_681b0_row6_col3" class="data row6 col3" >-5.864599</td>
#       <td id="T_681b0_row6_col4" class="data row6 col4" >-0.771677</td>
#       <td id="T_681b0_row6_col5" class="data row6 col5" >0.503445</td>
#       <td id="T_681b0_row6_col6" class="data row6 col6" >1.766212</td>
#       <td id="T_681b0_row6_col7" class="data row6 col7" >7.237837</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for column in df.columns:
    num_distinct_values = len(df[column].unique())
    print(f"{column}: {num_distinct_values} distinct values")
# Out:
# A_Id: 4001 distinct values
# Size: 4001 distinct values
# Weight: 4001 distinct values
# Sweetness: 4001 distinct values
# Crunchiness: 4001 distinct values
# Juiciness: 4001 distinct values
# Ripeness: 4001 distinct values
# Acidity: 4001 distinct values
# Quality: 3 distinct values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.isnull().any(axis = 1)]
# Out:
#       A_Id  Size  Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 4000   NaN   NaN     NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 4000  Created_by_Nidula_Elgiriyewithana     NaN

# %% [markdown]
# ## Análise Exploratória

# %%
def clean_data(df):
    
    df = df.drop(columns=['A_Id'])
    
    df = df.dropna()
    
    df = df.astype({'Acidity': 'float64'})
    
    def label(Quality):
        """
        Transform based on the following examples:
        Quality    Output
        "good"  => 0
        "bad"   => 1
        """
        if Quality == "good":
            return 0
    
        if Quality == "bad":
            return 1
    
        return None
    
    df['Target'] = df['Quality'].apply(label)
    
    df = df.drop(columns=['Quality'])
    
    df = df.astype({'Target': 'int64'})
    
    return df

df_clean = clean_data(df.copy())
df_clean.head()
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness   Acidity  \
# 0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840 -0.491590
# 1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530 -0.722809
# 2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033  2.621636
# 3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761  0.790723
# 4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849  0.501984
#
#    Target
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0

# %% [markdown]
# ## Visualização

# %% [markdown]
# <div style="background-color: #BEBADA; padding: 15px; border-radius: 10px;">
#     <p style="color: black; font-size: 14px; font-weight: bold;">
#       3.2.1  Univariate
#     </p>
# </div>

# %%
numerical_cols = ['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Acidity', 'Target']

plt.figure(figsize=(15, 10))
sns.set_palette("tab10")

for i, column in enumerate(numerical_cols, 1):
    plt.subplot(3, 3, i)
    sns.histplot(data=df_clean, x=column, kde=True, bins=20)  # Use sns.histplot for newer versions
    plt.title(column)

plt.tight_layout()
plt.show()

# %%
numerical_cols = ['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', 'Acidity','Target']

plt.figure(figsize=(15, 10))
sns.set_palette("Set1")
for i, column in enumerate(numerical_cols, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(y=df_clean[column])
    plt.title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #BEBADA; padding: 15px; border-radius: 10px;">
#     <p style="color: black; font-size: 14px; font-weight: bold;">
#       3.2.2  Bivariate
#     </p>
# </div>

# %%
plt.figure(figsize=(15, 10))
sns.set_palette("Set2")

for i, column in enumerate(df_clean.columns[:-1]):  
    plt.subplot(3, 3, i + 1)
    sns.boxplot(x='Target', y=column, data=df_clean)
    plt.title(f'{column} by Target')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #BEBADA; padding: 15px; border-radius: 10px;">
#     <p style="color: black; font-size: 14px; font-weight: bold;">
#       3.2.3  Multivariate
#     </p>
# </div>

# %%
plt.figure(figsize=(8, 8))
sns.set(style="white")  

sns.jointplot(x='Size', y='Weight', hue='Target', data=df_clean, palette='tab10', s=9)

# %%
plt.figure(figsize=(8, 8))
sns.set(style="white")  

sns.jointplot(x='Sweetness', y='Crunchiness', hue='Target', data=df_clean, palette='tab10', s=9)

# %%
plt.figure(figsize=(8, 8))
sns.set(style="white")  

sns.jointplot(x='Ripeness', y='Juiciness', hue='Target', data=df_clean, palette='tab10', s=9)

# %% [markdown]
# <div style="background-color: #BEBADA; padding: 15px; border-radius: 10px;">
#     <p style="color: black; font-size: 14px; font-weight: bold;">
#       3.3  Correlation Heatmap
#     </p>
# </div>

# %%
corr = df_clean.corr()

mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(15, 12))

cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# <div style="background-color: #BEBADA; padding: 15px; border-radius: 10px;">
#     <p style="color: black; font-size: 14px; font-weight: bold;">
#       4. Preprocesing
#     </p>
# </div>

# %% [markdown]
# <div style="background-color: #BEBADA; padding: 15px; border-radius: 10px;">
#     <p style="color: black; font-size: 14px; font-weight: bold;">
#       4.1  Outliers
#     </p>
# </div>

# %%
from sklearn.preprocessing import RobustScaler, StandardScaler

# %%
numerical_features = ['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness',
       'Acidity']

robust_scaler = RobustScaler()

df_clean[numerical_features] = robust_scaler.fit_transform(df_clean[numerical_features])

def count_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return ((series < lower_bound) | (series > upper_bound)).sum()

for feature in numerical_features :
    num_outliers = count_outliers(df_clean[feature])
    print(f'Number of outliers in {feature}: {num_outliers}')
# Out:
# Number of outliers in Size: 22
# Number of outliers in Weight: 54
# Number of outliers in Sweetness: 32
# Number of outliers in Crunchiness: 47
# Number of outliers in Juiciness: 32
# Number of outliers in Ripeness: 24
# Number of outliers in Acidity: 20

# %%
scaler = StandardScaler()

df_clean[numerical_features] = scaler.fit_transform(df_clean[numerical_features])

# %% [markdown]
# ## Save

# %%
df_clean.to_pickle(f"{ROOT}/data/apple.pickle")
